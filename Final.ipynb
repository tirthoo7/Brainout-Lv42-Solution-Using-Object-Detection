# %%
import cv2
import numpy as np
import os

# %%
def display(img):

    cv2.imshow('Display', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
def find_obj_fatch():
    
    image = cv2.imread('./objs.png')
    cv2.imshow('0 - Original Image', image)
    cv2.waitKey(0)

    # Create a black image with same dimensions as our loaded image(0->Black)
    blank_image = np.zeros((image.shape[0], image.shape[1], 3))

    # Create a copy of our original image
    orginal_image = image
    copy_orginal=image

    # Grayscale our image
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

    # Find Canny edges
    edged = cv2.Canny(gray, 50, 200)
    cv2.imshow('1 - Canny Edges', edged)
    cv2.waitKey(0)

    # Find contours and print how many were found
    contours, hierarchy = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    def x_cord_contour(contours):
        #Returns the X cordinate for the contour centroid
        if cv2.contourArea(contours) > 10:
            M = cv2.moments(contours)
            return (int(M['m10']/M['m00']))
        else:
            pass


    def label_contour_center(image, c):
        # Places a red circle on the centers of contours
        M = cv2.moments(c)
        cx = int(M['m10'] / M['m00'])
        cy = int(M['m01'] / M['m00'])

        # Draw the countour number on the image
        cv2.circle(image,(cx,cy), 10, (0,0,255), -1)
        return image


    # Load our image
    image = cv2.imread('./objs.png')
    orginal_image = image.copy()


    # Computer Center of Mass or centroids and draw them on our image
    for (i, c) in enumerate(contours):
        orig = label_contour_center(image, c)

    cv2.imshow("Contour Centers ", image)
    cv2.waitKey(0)

    # Sort by left to right using our x_cord_contour function
    contours_left_to_right = sorted(contours, key = x_cord_contour, reverse = False)


    # Labeling Contours left to right
    for (i,c)  in enumerate(contours_left_to_right):
    #     copy_orignal=orignal_image.copy()
        cv2.drawContours(orginal_image, [c], -1, (0,0,255), 3)  
        M = cv2.moments(c)
        cx = int(M['m10'] / M['m00'])
        cy = int(M['m01'] / M['m00'])
    #     cv2.putText(orginal_image, str(i+1), (cx, cy), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0))
        cv2.imshow('Left to Right Contour', orginal_image)
        cv2.waitKey(0)
        (x, y, w, h) = cv2.boundingRect(c)  
    #     return bounded rectangle

        # Let's now crop each contour and save these images
        cropped_contour = copy_orginal[y:y + h, x:x + w]
        image_name = "obj_number_" + str(i+1) + ".png"
        print (image_name)
        cv2.imwrite("./Objects_Identify/"+image_name, cropped_contour)
        cv2.imshow('Objects',cropped_contour)

    cv2.destroyAllWindows()

# %%
def target_img_seg():
    image = cv2.imread('./target_image.png')
    cv2.imshow('0 - Original Image', image)
    cv2.waitKey(0)

    # Create a black image with same dimensions as our loaded image(0->Black)
    blank_image = np.zeros((image.shape[0], image.shape[1], 3))

    # Create a copy of our original image
    orginal_image = image

    # Grayscale our image
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

    # Find Canny edges
    edged = cv2.Canny(gray, 50, 200)
    cv2.imshow('1 - Canny Edges', edged)
    cv2.waitKey(0)

    # Find contours and print how many were found
    contours, hierarchy = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    print ("Number of contours found = ", len(contours))

    #Draw all contours
    cv2.drawContours(blank_image, contours, -1, (0,255,0), 1)
    cv2.imshow('2 - All Contours over blank image', blank_image)
    cv2.waitKey(0)

    # Draw all contours over blank image
    cv2.drawContours(image, contours, -1, (0,255,0), 1)
    cv2.imshow('3 - All Contours', image)
    cv2.waitKey(0)
    # contours_left_to_right = sorted(contours, key = x_cord_contour, reverse = False)


    # Labeling Contours left to right
    for (i,c)  in enumerate(contours):
        (x, y, w, h) = cv2.boundingRect(c)  
    #     return bounded rectangle

        # Let's now crop each contour and save these images
        cropped_contour = orginal_image[y:y + h, x:x + w]
        image_name = "target_obj_number_" + str(i+1) + ".png"
        print (image_name)
        cv2.imwrite("./target_img_seg/"+image_name, cropped_contour)
        cv2.imshow('Target Image Segmentation',cropped_contour)

    cv2.destroyAllWindows()

# %%
def match():
    # Load input image and convert to grayscale
    image = cv2.imread('./target_image.png')
    display(image)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Load Template image
   
    
#     path='Objects_full_match/'
    path='Objects_Identify/'
    imagePaths=[os.path.join(path,f) for f in os.listdir(path)]
    for imagePath in imagePaths:
       
        
        template = cv2.imread(imagePath)
        cv2.imshow("Object To Found",template)
        cv2.waitKey(0)
        template = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)
        result = cv2.matchTemplate(gray, template, cv2.TM_CCOEFF)
        min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

        #Create Bounding Box
        top_left = max_loc
        bottom_right = (top_left[0] + 50, top_left[1] + 50)
        cv2.rectangle(image, top_left, bottom_right, (0,0,255), 3)
        display(image)

# %%
match()

# %%
target_img_seg()
# Out:
# ('Number of contours found = ', 645)
# target_obj_number_1.png
# target_obj_number_2.png
# target_obj_number_3.png
# target_obj_number_4.png
# target_obj_number_5.png
# target_obj_number_6.png
# target_obj_number_7.png
# target_obj_number_8.png
# target_obj_number_9.png
# target_obj_number_10.png
# target_obj_number_11.png
# target_obj_number_12.png
# target_obj_number_13.png
# target_obj_number_14.png
# target_obj_number_15.png
# target_obj_number_16.png
# target_obj_number_17.png
# target_obj_number_18.png
# target_obj_number_19.png
# target_obj_number_20.png
# target_obj_number_21.png
# target_obj_number_22.png
# target_obj_number_23.png
# target_obj_number_24.png
# target_obj_number_25.png
# target_obj_number_26.png
# target_obj_number_27.png
# target_obj_number_28.png
# target_obj_number_29.png
# target_obj_number_30.png
# target_obj_number_31.png
# target_obj_number_32.png
# target_obj_number_33.png
# target_obj_number_34.png
# target_obj_number_35.png
# target_obj_number_36.png
# target_obj_number_37.png
# target_obj_number_38.png
# target_obj_number_39.png
# target_obj_number_40.png
# target_obj_number_41.png
# target_obj_number_42.png
# target_obj_number_43.png
# target_obj_number_44.png
# target_obj_number_45.png
# target_obj_number_46.png
# target_obj_number_47.png
# target_obj_number_48.png
# target_obj_number_49.png
# target_obj_number_50.png
# target_obj_number_51.png
# target_obj_number_52.png
# target_obj_number_53.png
# target_obj_number_54.png
# target_obj_number_55.png
# target_obj_number_56.png
# target_obj_number_57.png
# target_obj_number_58.png
# target_obj_number_59.png
# target_obj_number_60.png
# target_obj_number_61.png
# target_obj_number_62.png
# target_obj_number_542.png
# target_obj_number_543.png
# target_obj_number_544.png
# target_obj_number_545.png
# target_obj_number_546.png
# target_obj_number_547.png
# target_obj_number_548.png
# target_obj_number_549.png
# target_obj_number_550.png
# target_obj_number_551.png
# target_obj_number_552.png
# target_obj_number_553.png
# target_obj_number_554.png
# target_obj_number_555.png
# target_obj_number_556.png
# target_obj_number_557.png
# target_obj_number_558.png
# target_obj_number_559.png
# target_obj_number_560.png
# target_obj_number_561.png
# target_obj_number_562.png
# target_obj_number_563.png
# target_obj_number_564.png
# target_obj_number_565.png
# target_obj_number_566.png
# target_obj_number_567.png
# target_obj_number_568.png
# target_obj_number_569.png
# target_obj_number_570.png
# target_obj_number_571.png
# target_obj_number_572.png
# target_obj_number_573.png
# target_obj_number_574.png
# target_obj_number_575.png
# target_obj_number_576.png
# target_obj_number_577.png
# target_obj_number_578.png
# target_obj_number_579.png
# target_obj_number_580.png
# target_obj_number_581.png
# target_obj_number_582.png
# target_obj_number_583.png
# target_obj_number_584.png
# target_obj_number_585.png
# target_obj_number_586.png
# target_obj_number_587.png
# target_obj_number_588.png
# target_obj_number_589.png
# target_obj_number_590.png
# target_obj_number_591.png
# target_obj_number_592.png
# target_obj_number_593.png
# target_obj_number_594.png
# target_obj_number_595.png
# target_obj_number_596.png
# target_obj_number_597.png
# target_obj_number_598.png
# target_obj_number_599.png
# target_obj_number_600.png
# target_obj_number_601.png
# target_obj_number_602.png
# target_obj_number_603.png
# target_obj_number_604.png
# target_obj_number_605.png
# target_obj_number_606.png
# target_obj_number_607.png
# target_obj_number_608.png
# target_obj_number_609.png
# target_obj_number_610.png
# target_obj_number_611.png
# target_obj_number_612.png
# target_obj_number_613.png
# target_obj_number_614.png
# target_obj_number_615.png
# target_obj_number_616.png
# target_obj_number_617.png
# target_obj_number_618.png
# target_obj_number_619.png
# target_obj_number_620.png
# target_obj_number_621.png
# target_obj_number_622.png
# target_obj_number_623.png
# target_obj_number_624.png
# target_obj_number_625.png
# target_obj_number_626.png
# target_obj_number_627.png
# target_obj_number_628.png
# target_obj_number_629.png
# target_obj_number_630.png
# target_obj_number_631.png
# target_obj_number_632.png
# target_obj_number_633.png
# target_obj_number_634.png
# target_obj_number_635.png
# target_obj_number_636.png
# target_obj_number_637.png
# target_obj_number_638.png
# target_obj_number_639.png
# target_obj_number_640.png
# target_obj_number_641.png
# target_obj_number_642.png
# target_obj_number_643.png
# target_obj_number_644.png
# target_obj_number_645.png

# %%
find_obj_fatch()
# Out:
# obj_number_1.png
# obj_number_2.png
# obj_number_3.png
# obj_number_4.png
# obj_number_5.png
# obj_number_6.png
# obj_number_7.png
# obj_number_8.png
# obj_number_9.png
# obj_number_10.png
# obj_number_11.png
# obj_number_12.png
# obj_number_13.png
# obj_number_14.png
# obj_number_15.png
# obj_number_16.png
# obj_number_17.png
